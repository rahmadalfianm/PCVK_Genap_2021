# %% [markdown]
# <a href="https://colab.research.google.com/github/rahmadalfianm/PCVK_Genap_2021/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpg')
plt.imshow(img)

# %%
img = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)   #konversi channel BGR  ->  RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten02.jpg',cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)
plt.imshow(img_gray,cmap='gray')
plt.imshow(img_gray,cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))   #konversi channel BGR  ->  RGB
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)
#simpan file image
#cv.imwrite('/content/drive/MyDrive/PCVK_MM/Images/mandirill2.tiff',img5)

#tampilkan plot dengan ukuran canvas yg lebih besar
fig = plt.figure(figsize=(10,10))   #ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# **Jawaban Pertanyaan**
# 1. Jika menggunakan library matplotlib setiap sumbu memiliki sumbu horizontal (x) dan sumbu vertikal (y), dan data yang direpresentasikan menjadi warna dan glyphs seperti marker (contohnya bentuk lingkaran) atau lines (garis) atau poligon.
#
# 2. Hanya berbeda rentang jarak dtype int16 32768 hingga 32767 dan int32 -231 hingga 231 - 1 , dan tidak ada pengaruh untuk gambarnya (hanya beda nilai intensitas gambarnya saja)
#
# 3. (-1,1,2) berarti matriks dengan jumlah baris yang tidak diketahui tetapi satu kolom dan setiap elemen dengan 2 sub-elemen.
#
# 4. Sebagai patches untuk menampilkan gambar di google colab
#
# 5. skimage import io memiliki fungsi untuk mengkonversi gambar ndarray, seperti rgb2gray

# %% [markdown]
# TUGAS

# %%
#Soal no 1
#RedGreen
img_rg = img.copy()
img_rg[:,:,2] = 0
plt.imshow(img_rg)

# %%
#GreenBlue
img_gb = img
img_gb[:,:,0] = 0
plt.imshow(img_gb)

# %%
#Soal no 2
#Baris ke 10-100 & Kolom ke 10-100
img_BK = img[10:100,10:100]
plt.imshow(img_BK)

# %%
#Soal no 3
#Baris ke 5-30 & Channel green saja
cropImg = img[5:30,0:500]
cropImg[:,:,0] = 0
cropImg[:,:,2] = 0
plt.imshow(cropImg)

# %%
#Soal no 4
#Buat 5 Kotak
imageWithRectangle = cv.cvtColor(img,cv.COLOR_BGR2RGB)
fig = plt.figure(figsize=(10,10))
cv.rectangle(imageWithRectangle, pt1=(50,200), pt2=(20,95), color=(0,200,20), thickness = 3)
cv.rectangle(imageWithRectangle, pt1=(20,20), pt2=(50,67), color=(0,255,0), thickness = -4)
cv.rectangle(imageWithRectangle, pt1=(200,200), pt2=(255,361), color=(255,200,0), thickness = -1)
cv.rectangle(imageWithRectangle, pt1=(350,350), pt2=(402,210), color=(255,10,60), thickness = 5)
cv.rectangle(imageWithRectangle, pt1=(500,150), pt2=(600,100), color=(250,250,50),thickness=6)
plt.imshow(imageWithRectangle)

# %%
#Soal no 5
#Tampilkan image dengan posisi terbalik
flippedImg = cv.flip(imageWithRectangle, 0)
plt.imshow(flippedImg)

# %%
#Soal no 6
#Buat Rectangle dan Circle pada bagian wajah dari image kitten
img = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpg')
fig = plt.figure(figsize=(5,5))

ax = fig.add_subplot(111)
cv.rectangle(img, pt1=(200,70), pt2=(750,420), color=(0,200,250), thickness = 20)
cv.circle(img, center=(480, 260), radius=80, color=(0,0,255), thickness = -1)
ax.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))

# %%
#Soal no 7
#Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten01.jpg
img = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpg')
fig = plt.figure(figsize=(5,5))

ax = fig.add_subplot(111)
cv.rectangle(img, pt1=(200,70), pt2=(750,420), color=(0,200,250), thickness = 20)
cv.circle(img, center=(480, 260), radius=80, color=(0,0,255), thickness = -1)
cv.rectangle(img,pt1=(100,500),pt2=(30,400),color=(0,255,0),thickness = 15)
ax.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
