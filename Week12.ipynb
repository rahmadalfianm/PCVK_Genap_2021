# %% [markdown]
# <a href="https://colab.research.google.com/github/rahmadalfianm/PCVK_Genap_2021/blob/main/Week12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Import Library**

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from base64 import b64decode, b64encode

# %% [markdown]
# **Load images from drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **(2) Lakukan Face Detection untuk image object lain yang tersedia pada (/images/facedet)**

# %%
frontal_face = cv.CascadeClassifier('/content/drive/MyDrive/PCVK_MM/Images/haarcascades/haarcascade_frontalface_alt.xml')

jokowi = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/facedet/jokowi.jpg')
jokowi1 = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/facedet/jokowi.jpg')
detect = frontal_face.detectMultiScale(jokowi1)

for(x,y,w,h) in detect: 
 cv.rectangle(jokowi1,(x,y),(x+w,y+h),(0,255,0),3) 
plt.figure(figsize = (10,10)) 

plt. subplots(1,2,figsize=(10,5))
plt.subplot(121),plt.imshow(cv.cvtColor(jokowi, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(cv.cvtColor(jokowi1, cv.COLOR_BGR2RGB))
plt.show()

# %%
ibukartini = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/facedet/kartini.jpg')
ibukartini1 = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/facedet/kartini.jpg')
detect = frontal_face.detectMultiScale(ibukartini1)
 
for(x,y,w,h) in detect: 
 cv.rectangle(ibukartini1,(x,y),(x+w,y+h),(0,255,0),3) 
plt.figure(figsize = (10,10)) 

plt. subplots(1,2,figsize=(10,5))
plt.subplot(121),plt.imshow(cv.cvtColor(ibukartini, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(cv.cvtColor(ibukartini1, cv.COLOR_BGR2RGB))
plt.show()

# %%
kucing = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/facedet/kucing.jpg')
kucing1 = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/facedet/kucing.jpg')
detect = frontal_face.detectMultiScale(kucing1)

kucinggray = cv.cvtColor(kucing, cv.COLOR_BGR2GRAY)
kucinggray1 = cv.cvtColor(kucing1, cv.COLOR_BGR2GRAY)
 
for(x,y,w,h) in detect: 
 cv.rectangle(kucing1,(x,y),(x+w,y+h),(0,255,0),3) 
plt.figure(figsize = (10,10)) 

plt. subplots(1,2,figsize=(10,5))
plt.subplot(121),plt.imshow(kucinggray, cmap='gray')
plt.subplot(122),plt.imshow(kucinggray1, cmap='gray')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f88a2e6b950>,
#  <matplotlib.image.AxesImage at 0x7f88a2de0b10>)

# %%
mbakMasker = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/facedet/mask.png')
mbakMasker1 = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/facedet/mask.png')

mbakMaskergray = cv.cvtColor(mbakMasker, cv.COLOR_BGR2GRAY)
mbakMaskergray1 = cv.cvtColor(mbakMasker1, cv.COLOR_BGR2GRAY)
detect = frontal_face.detectMultiScale(mbakMaskergray1)
 
for(x,y,w,h) in detect: 
 cv.rectangle(mbakMaskergray1,(x,y),(x+w,y+h),(0,255,0),3) 
plt.figure(figsize = (10,10)) 

plt. subplots(1,2,figsize=(10,5))
plt.subplot(121),plt.imshow(mbakMaskergray, cmap='gray')
plt.subplot(122),plt.imshow(mbakMaskergray1, cmap='gray')
plt.show()

# %%
jordan = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/facedet/mjordan.jpg',0)
jordan1 = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/facedet/mjordan.jpg',0)
detect = frontal_face.detectMultiScale(jordan1)

for(x,y,w,h) in detect:
 cv.rectangle(jordan1,(x,y),(x+w,y+h),(0,255,0),3)
plt.figure(figsize = (10,10))

plt. subplots(1,2,figsize=(10,5))
plt.subplot(121),plt.imshow(jordan, cmap='gray')
plt.subplot(122),plt.imshow(jordan1, cmap='gray')
plt.show()

# %%
fotoBareng = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/facedet/solvayconf.jpg',0)
fotoBareng1 = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/facedet/solvayconf.jpg',0)
detect = frontal_face.detectMultiScale(fotoBareng1)

for(x,y,w,h) in detect:
 cv.rectangle(fotoBareng1,(x,y),(x+w,y+h),(0,255,0),3)
plt.figure(figsize = (10,10))

plt. subplots(1,2,figsize=(10,5))
plt.subplot(121),plt.imshow(fotoBareng, cmap='gray')
plt.subplot(122),plt.imshow(fotoBareng1, cmap='gray')
plt.show()

# %% [markdown]
# **(3) Pada Soal No.2. wajah kucing tidak bisa dideteksi dengan baik. Lakukan deteksi wajah kucing hingga muncul rectangle pada bagian wajahnya. Petunjuk pada soal ini perhatikan pretrained features yang telah disediakan OpenCV. Gunakan xml yang ada jika memang telah disediakan Jika belum ada, coba cari dengan searching melalui search engines**

# %%
frontal_catface = cv.CascadeClassifier('/content/drive/MyDrive/PCVK_MM/Images/haarcascades/haarcascade_frontalcatface.xml')
kucingg = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/facedet/kucing.jpg',0)
kucingg1 = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/facedet/kucing.jpg',0)
detect = frontal_catface.detectMultiScale(kucingg1)

for(x,y,w,h) in detect:
 cv.rectangle(kucingg1,(x,y),(x+w,y+h),(0,255,0),3)
plt.figure(figsize = (10,10))

plt. subplots(1,2,figsize=(10,5))
plt.subplot(121),plt.imshow(kucingg, cmap='gray')
plt.subplot(122),plt.imshow(kucingg1, cmap='gray')
plt.show()

# %% [markdown]
# **(4) Cobakan juga untuk eyes detection**

# %%
eyeDetection = cv.CascadeClassifier('/content/drive/MyDrive/PCVK_MM/Images/haarcascades/haarcascade_lefteye_2splits.xml')
mataJokowi = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/facedet/jokowi.jpg')
mataJokowi1 = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/facedet/jokowi.jpg')

mataJokowigray = cv.cvtColor(mataJokowi, cv.COLOR_BGR2GRAY)
mataJokowigray1 = cv.cvtColor(mataJokowi1, cv.COLOR_BGR2GRAY)
detect = eyeDetection.detectMultiScale(mataJokowigray1)
 
for(x,y,w,h) in detect: 
 cv.rectangle(mataJokowigray1,(x,y),(x+w,y+h),(255,255,255),3) 
plt.figure(figsize = (10,10)) 

plt. subplots(1,2,figsize=(10,5))
plt.subplot(121),plt.imshow(mataJokowigray, cmap='gray')
plt.subplot(122),plt.imshow(mataJokowigray1, cmap='gray')
plt.show()

# %% [markdown]
# **(5) Lakukan Face Tracking menggunakan Google Colab Petunjuk, Tutorial selengkapnya tentang akses kamera dan FaceDetection pada google colab dapat dilihat di link berikut: https://www.youtube.com/watch?v=YjWh7QvVH60**

# %%
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from base64 import b64decode, b64encode
import cv2
import numpy as np
import PIL
import io
import html
import time

# %%
def js_to_image(js_reply):
  """
  Params:
          js_reply: JavaScript object containing image from webcam
  Returns:
          img: OpenCV BGR image
  """
  # decode base64 image
  image_bytes = b64decode(js_reply.split(',')[1])
  # convert bytes to numpy array
  jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8)
  # decode numpy array into OpenCV BGR image
  img = cv2.imdecode(jpg_as_np, flags=1)

  return img

# function to convert OpenCV Rectangle bounding box image into base64 byte string to be overlayed on video stream
def bbox_to_bytes(bbox_array):
  """
  Params:
          bbox_array: Numpy array (pixels) containing rectangle to overlay on video stream.
  Returns:
        bytes: Base64 image byte string
  """
  # convert array into PIL image
  bbox_PIL = PIL.Image.fromarray(bbox_array, 'RGBA')
  iobuf = io.BytesIO()
  # format bbox into png for return
  bbox_PIL.save(iobuf, format='png')
  # format return string
  bbox_bytes = 'data:image/png;base64,{}'.format((str(b64encode(iobuf.getvalue()), 'utf-8')))

  return bbox_bytes

# %%
face_cascade = cv2.CascadeClassifier(cv2.samples.findFile(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'))

# %%
def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)

  # get photo data
  data = eval_js('takePhoto({})'.format(quality))
  # get OpenCV format image
  img = js_to_image(data) 
  # grayscale img
  gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
  print(gray.shape)
  # get face bounding box coordinates using Haar Cascade
  faces = face_cascade.detectMultiScale(gray)
  # draw face bounding box on image
  for (x,y,w,h) in faces:
      img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
  # save image
  cv2.imwrite(filename, img)

  return filename

# %%
try:
  filename = take_photo('photo.jpg')
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
# Out:
# (480, 640)
# Saved to photo.jpg

# %% [markdown]
# **(6) Lakukan Blurring pada bagian wajah yang terdeteksi. Berikut contoh keluarannya. Petunjuk: anda dapat menggunakan cv.medianBlur untuk melakukan Blurring**

# %%
frontal_face = cv.CascadeClassifier('/content/drive/MyDrive/PCVK_MM/Images/haarcascades/haarcascade_frontalface_alt.xml') 
blurJordan = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/facedet/mjordan.jpg')
blurJordan1 = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/facedet/mjordan.jpg')
blurJordangray = cv.cvtColor(blurJordan, cv.COLOR_BGR2GRAY)
blurJordangray1 = cv.cvtColor(blurJordan1, cv.COLOR_BGR2GRAY)
detect = frontal_face.detectMultiScale(blurJordangray1) 
kernel = 15

for(x,y,w,h) in detect: 
 median = cv.medianBlur(blurJordangray1[x:x+w, y:y+h], kernel)
for(x,y,w,h) in detect: 
 blurJordangray1[x:x+w, y:y+h] = median

plt. subplots(1,2,figsize=(10,5))
plt.subplot(121),plt.imshow(blurJordangray, cmap='gray')
plt.subplot(122),plt.imshow(blurJordangray1, cmap='gray')
plt.show()
